# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data/2021-2022 NBA Player Stats.csv", sep=";")
df
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0      1   Precious Achiuwa   C   22  TOR  64  27  23.6  3.6   8.2  ...
# 1      2       Steven Adams   C   28  MEM  70  69  26.4  2.8   5.1  ...
# 2      3        Bam Adebayo   C   24  MIA  48  48  32.9  7.3  13.4  ...
# 3      4       Santi Aldama  PF   21  MEM  28   0  10.5  1.3   3.6  ...
# 4      5  LaMarcus Aldridge   C   36  BRK  45  12  22.8  5.6  10.1  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 784  593     Thaddeus Young  PF   33  TOR  17   0  17.4  2.4   5.3  ...
# 785  594         Trae Young  PG   23  ATL  67  67  34.9  9.3  20.3  ...
# 786  595     Omer Yurtseven   C   23  MIA  50  11  12.6  2.4   4.5  ...
# 787  596        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  ...
# 788  597        Ivica Zubac   C   24  LAC  68  68  24.4  4.0   6.4  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# Rk : Rank
# Player : Player's name
# Pos : Position
# Age : Player's age
# Tm : Team
# G : Games played
# GS : Games started
# MP : Minutes played per game
# FG : Field goals per game
# FGA : Field goal attempts per game
# FG% : Fiel goal percentage
# 3P : 3-point field goals per game
# 3PA : 3-point field goal attempts per game
# 3P% : 3-point field goal percentage
# 2P : 2-point field goals per game
# 2PA : 2-point field goal attempts per game
# 2P% : 2-point field goal percentage
# eFG% : Effective field goal percentage
# FT : Free throws per game
# FTA : Free throw attempts per game
# FT% : Free throw percentage
# ORB : Offensive rebounds per game
# DRB : Defensive rebounds per game
# TRB : Total rebounds per game
# AST : Assists per game
# STL : Steals per game
# BLK : Blocks per game
# TOV : Turnovers per game
# PF : Personal fouls per game
# PTS : Points per game

# %%
df = df.drop(columns=['Rk'])
df
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0     Precious Achiuwa   C   22  TOR  64  27  23.6  3.6   8.2  0.437  ...
# 1         Steven Adams   C   28  MEM  70  69  26.4  2.8   5.1  0.550  ...
# 2          Bam Adebayo   C   24  MIA  48  48  32.9  7.3  13.4  0.547  ...
# 3         Santi Aldama  PF   21  MEM  28   0  10.5  1.3   3.6  0.370  ...
# 4    LaMarcus Aldridge   C   36  BRK  45  12  22.8  5.6  10.1  0.554  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 784     Thaddeus Young  PF   33  TOR  17   0  17.4  2.4   5.3  0.456  ...
# 785         Trae Young  PG   23  ATL  67  67  34.9  9.3  20.3  0.457  ...
# 786     Omer Yurtseven   C   23  MIA  50  11  12.6  2.4   4.5  0.540  ...
# 787        Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 788        Ivica Zubac   C   24  LAC  68  68  24.4  4.0   6.4  0.624  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.groupby("Tm").mean()
# Out:
#            Age          G         GS         MP        FG       FGA       FG%  \
# Tm
# ATL  25.958333  32.875000  15.208333  18.595833  2.879167  6.233333  0.428417
# BOS  26.692308  30.769231  14.230769  14.396154  2.265385  5.015385  0.403962
# BRK  28.541667  32.250000  15.208333  20.720833  3.566667  7.570833  0.436083
# CHI  25.272727  34.000000  16.590909  18.086364  2.850000  5.945455  0.478000
# CHO  24.947368  38.736842  19.210526  18.263158  3.142105  6.742105  0.437789
# CLE  26.076923  29.846154  14.038462  17.280769  2.796154  6.123077  0.452385
# DAL  26.592593  30.111111  13.518519  15.822222  2.559259  5.922222  0.382370
# DEN  26.454545  37.181818  16.818182  17.209091  2.795455  6.050000  0.453455
# DET  24.160000  30.320000  14.600000  19.736000  2.700000  6.720000  0.367240
# GSW  27.411765  48.235294  21.470588  19.794118  3.229412  6.976471  0.473882
# HOU  24.526316  41.157895  19.210526  19.636842  3.089474  6.900000  0.451105
# ...

# %%
df.groupby("Pos").mean()
# Out:
#              Age          G         GS         MP        FG        FGA  \
# Pos
# C      26.713178  36.418605  18.620155  16.693023  2.910078   5.364341
# C-PF   28.500000  56.500000  36.000000  25.450000  4.900000   9.000000
# PF     26.013333  34.053333  15.106667  17.694667  2.800667   5.944000
# PF-SF  31.000000  63.000000  40.000000  27.800000  2.800000   6.900000
# PG     26.589404  31.298013  15.496689  19.317881  2.996026   7.229801
# PG-SG  32.000000  56.000000  56.000000  37.200000  6.500000  15.600000
# SF     25.578947  32.868421  13.861842  17.089474  2.562500   5.928289
# SF-SG  27.833333  41.500000  16.833333  18.966667  2.650000   6.433333
# SG     25.659686  33.078534  13.125654  18.337696  2.793717   6.672251
# SG-PG  24.000000  60.000000  35.666667  26.533333  4.066667   9.633333
# SG-SF  26.666667  32.333333  18.666667  24.033333  3.533333   8.000000
#
#             FG%        3P       3PA       3P%  ...       FT%       ORB  \
# ...

# %%
df["Player"].count()
# Out:
# 789

# %%
Efficiency = df.PTS + df.TRB + df.AST + df.STL + df.BLK - (df.FGA - df.FG) - (df.FTA - df.FT) - df.TOV
df.insert(29, "EFF", Efficiency)
df.head(10)
# Out:
#                      Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  \
# 0          Precious Achiuwa   C   22  TOR  64  27  23.6  3.6   8.2  0.437
# 1              Steven Adams   C   28  MEM  70  69  26.4  2.8   5.1  0.550
# 2               Bam Adebayo   C   24  MIA  48  48  32.9  7.3  13.4  0.547
# 3              Santi Aldama  PF   21  MEM  28   0  10.5  1.3   3.6  0.370
# 4         LaMarcus Aldridge   C   36  BRK  45  12  22.8  5.6  10.1  0.554
# 5  Nickeil Alexander-Walker  SG   23  TOT  61  21  23.5  4.1  11.0  0.372
# 6  Nickeil Alexander-Walker  SG   23  NOP  50  19  26.3  4.7  12.6  0.375
# 7  Nickeil Alexander-Walker  SG   23  UTA  11   2  10.7  1.1   3.4  0.324
# 8             Grayson Allen  SG   26  MIL  61  60  27.4  3.9   8.9  0.443
# 9             Jarrett Allen   C   23  CLE  56  56  32.3  6.6   9.7  0.677
#
#    ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS   EFF
# 0  ...  2.1  4.7   6.8  1.1  0.5  0.5  1.1  2.1   8.8  11.3
# ...

# %%
players_C = df[df.Pos == "C"]
players_PG = df[df.Pos == "PG"]
players_SG = df[df.Pos == "SG"]
players_PF = df[df.Pos == "PF"]
players_SF = df[df.Pos == "SF"]

players_PG.head(10)
# Out:
#               Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 10     Jose Alvarado  PG   23  NOP  45   1  15.0  2.2   5.2  0.427  ...  0.5
# 18      Cole Anthony  PG   21  ORL  60  60  32.5  5.7  14.4  0.394  ...  0.5
# 20  Ryan Arcidiacono  PG   27  NYK   6   0   2.8  0.3   0.5  0.667  ...  0.0
# 22     D.J. Augustin  PG   34  TOT  46   2  15.7  1.8   4.1  0.439  ...  0.2
# 23     D.J. Augustin  PG   34  HOU  34   2  15.0  1.6   4.0  0.404  ...  0.2
# 24     D.J. Augustin  PG   34  LAL  12   0  17.5  2.3   4.3  0.529  ...  0.2
# 32       LaMelo Ball  PG   20  CHO  66  66  32.2  7.0  16.6  0.425  ...  1.5
# 33        Lonzo Ball  PG   24  CHI  35  35  34.6  4.6  10.9  0.423  ...  1.0
# 37        Cat Barber  PG   27  ATL   3   0   4.3  0.0   1.3  0.000  ...  0.3
# 57  Patrick Beverley  PG   33  MIN  52  48  25.7  3.1   7.7  0.407  ...  1.1
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS   EFF
# 10  1.3  1.8  2.7  1.3  0.1  0.7  1.5   5.8   7.7
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True);

# %%
plt.figure(figsize=(14,6))
sns.swarmplot(x=df["Pos"],
              y=df["PTS"])
# Out:
# <AxesSubplot:xlabel='Pos', ylabel='PTS'>

# %%
print("Points mean C: " + str(round(players_C.PTS.mean())))
print("Points mean PG: " + str(round(players_PG.PTS.mean())))
print("Points mean SG: " + str(round(players_SG.PTS.mean())))
print("Points mean PF: " + str(round(players_PF.PTS.mean())))
print("Points mean SF: " + str(round(players_SF.PTS.mean())))
# Out:
# Points mean C: 7
# Points mean PG: 8
# Points mean SG: 8
# Points mean PF: 8
# Points mean SF: 7

# %%
plt.figure(figsize=(14,6))
sns.swarmplot(x=df["Pos"],
              y=df["EFF"]);

# %%
print("Efficiency mean C: " + str(round(players_C.EFF.mean())))
print("Efficiency mean PG: " + str(round(players_PG.EFF.mean())))
print("Efficiency mean SG: " + str(round(players_SG.EFF.mean())))
print("Efficiency mean PF: " + str(round(players_PF.EFF.mean())))
print("Efficiency mean SF: " + str(round(players_SF.EFF.mean())))
# Out:
# Efficiency mean C: 11
# Efficiency mean PG: 9
# Efficiency mean SG: 8
# Efficiency mean PF: 9
# Efficiency mean SF: 8

# %%
plt.figure(figsize=(14,6))
sns.swarmplot(x=df["Age"],
              y=df["PTS"]);

# %%
print(df.Player[(df.Age>=30) & (df.PTS>=25)])
# Out:
# 158    Stephen Curry
# 166    DeMar DeRozan
# 197     Kevin Durant
# 364     LeBron James
# 479      CJ McCollum
# Name: Player, dtype: object

# %%
plt.figure(figsize=(15,10))
sns.set_style("darkgrid")
sns.scatterplot('Age','PTS',hue='Pos',data=df)
plt.xlabel('Age')
plt.ylabel('Points per Game')
plt.title('Age vs Points per Game')
plt.text(df.Age[df.Player=="LeBron James"]+0.3,df.PTS[df.Player=="LeBron James"]+0.3,"Lebron James", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="DeMar DeRozan"]+0.3,df.PTS[df.Player=="DeMar DeRozan"]+0.3,"DeMar DeRozan", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="Kevin Durant"]+0.3,df.PTS[df.Player=="Kevin Durant"]+0.3,"Kevin Durant", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="Stephen Curry"]+0.3,df.PTS[df.Player=="Stephen Curry"]+0.3,"Stephen Curry", color='black',bbox=dict(facecolor='yellow',alpha=0.5))

plt.legend(title='Position');

# %%
Cs = pd.DataFrame(players_C.Player[(players_C.Age<=23)&(players_C.PTS>=15)&(players_C.EFF>=12)]).rename(columns={"Player": "Centers"}).reset_index(drop=True)
PGs = pd.DataFrame(players_PG.Player[(players_PG.Age<=23)&(players_PG.PTS>=15)&(players_PG.EFF>=12)]).rename(columns={"Player": "Point Guards"}).reset_index(drop=True)
SGs = pd.DataFrame(players_SG.Player[(players_SG.Age<=23)&(players_SG.PTS>=15)&(players_SG.EFF>=12)]).rename(columns={"Player": "Shooting Guards"}).reset_index(drop=True)
PFs = pd.DataFrame(players_PF.Player[(players_PF.Age<=23)&(players_PF.PTS>=15)&(players_PF.EFF>=12)]).rename(columns={"Player": "Power Forwards"}).reset_index(drop=True)
SFs = pd.DataFrame(players_SF.Player[(players_SF.Age<=23)&(players_SF.PTS>=15)&(players_SF.EFF>=12)]).rename(columns={"Player": "Small Forwards"}).reset_index(drop=True)

future = pd.concat([Cs, PGs, SGs, PFs, SFs], axis=1, join="outer")
future
# Out:
#               Centers             Point Guards  Shooting Guards  \
# 0       Jarrett Allen             Cole Anthony  Anthony Edwards
# 1       Deandre Ayton              LaMelo Ball      Jalen Green
# 2  Wendell Carter Jr.          Cade Cunningham      Tyler Herro
# 3                 NaN              Luka Don?i?     Jordan Poole
# 4                 NaN           Darius Garland  Anfernee Simons
# 5                 NaN  Shai Gilgeous-Alexander   Gary Trent Jr.
# 6                 NaN        Tyrese Haliburton              NaN
# 7                 NaN             Tyrese Maxey              NaN
# 8                 NaN                Ja Morant              NaN
# 9                 NaN               Trae Young              NaN
#
#       Power Forwards  Small Forwards
# 0     Scottie Barnes    Desmond Bane
# 1      Miles Bridges      RJ Barrett
# 2  Jaren Jackson Jr.      Saddiq Bey
# 3        Evan Mobley   Luguentz Dort
# 4                NaN  Keldon Johnson
# ...

# %%
plt.figure(figsize=(15,10))
sns.set_style("darkgrid")
sns.scatterplot('Age','PTS',hue='Pos',data=df)
plt.xlabel('Age')
plt.ylabel('Points per Game')
plt.title('Age vs Points per Game')
plt.text(df.Age[df.Player=="LeBron James"]+0.3,df.PTS[df.Player=="LeBron James"]+0.3,"Lebron James", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="DeMar DeRozan"]+0.3,df.PTS[df.Player=="DeMar DeRozan"]+0.3,"DeMar DeRozan", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="Kevin Durant"]+0.3,df.PTS[df.Player=="Kevin Durant"]+0.3,"Kevin Durant", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="Stephen Curry"]+0.3,df.PTS[df.Player=="Stephen Curry"]+0.3,"Stephen Curry", color='black',bbox=dict(facecolor='yellow',alpha=0.5))
plt.text(df.Age[df.Player=="LaMelo Ball"]-1.8,df.PTS[df.Player=="LaMelo Ball"]+0.3,"LaMelo Ball", color='black',bbox=dict(facecolor='blue',alpha=0.5))
plt.text(df.Age[df.Player=="Trae Young"]+0.3,df.PTS[df.Player=="Trae Young"]+0.3,"Trae Young", color='black',bbox=dict(facecolor='blue',alpha=0.5))
plt.text(df.Age[df.Player=="Luka Don?i?"]-2.0,df.PTS[df.Player=="Luka Don?i?"]+0.3,"Luka Doncic", color='black',bbox=dict(facecolor='blue',alpha=0.5))
plt.text(df.Age[df.Player=="Ja Morant"]-1.7,df.PTS[df.Player=="Ja Morant"]-0.5,"Ja Morant", color='black',bbox=dict(facecolor='blue',alpha=0.5))



plt.legend(title='Position');
